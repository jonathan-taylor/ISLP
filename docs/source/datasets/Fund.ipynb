# %% [markdown]
# # Fund Manager Data
#
# A simulated data set containing the returns for 2,000 hedge fund
# managers.

# %%
from ISLP import load_data
Fund = load_data('Fund')
Fund.columns

# %%
Fund.shape

# %%
Fund.columns
